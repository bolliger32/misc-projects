# %% [markdown]
# import modules

# %%
import pandas as pd

# %% [markdown]
# #####

# %%
data = pd.read_csv("/Users/ianbolliger/Google Drive/ER 254 Group Project - Overgeneration + DR_Storage/Modeling/Data/All_PNodes_LMP_Aggregated_2013short.csv")

# %%
data.columns[-2]
# Out:
# '2013-12-31 00:00:00.0_HE23'

# %%
data
# Out:
#            Unnamed: 0  2013-01-01 00:00:00.0_HE01  2013-01-01 00:00:00.0_HE02  \
# 0      ACTONSC_6_N001                    35.62509                    32.26346
# 1         ADCC_2_N001                    33.53629                    32.13152
# 2       AEC300_1_N001                    33.62979                    32.23174
# 3        AGNEW_1_N003                    34.43316                    32.91388
# 4      AIRPROD_1_N001                    34.97683                    33.40205
# 5     ALAMITOS_2_N001                    35.88035                    32.56174
# 6     ALAMITOS_2_N040                    35.88035                    32.56174
# 7        ALAMT1G_7_B1                    35.88035                    32.56174
# 8      ALAMT1G_7_N002                    35.88035                    32.56174
# 9        ALAMT2G_7_B1                    35.88035                    32.56174
# 10     ALAMT2G_7_N002                    35.88035                    32.56174
# ...
